# %%
import pandas as pd
import numpy as np
import json
import os
from sqlalchemy import create_engine
import pymysql

# %%
def read_data(sql):
    host = '127.0.0.1'  #ip
    port = 3306  #埠號
    user = 'teb101Club'   #資料庫使用者名稱
    password = 'teb101Club'    #資料庫密碼
    db = 'twstock'    #資料庫名
    
    try:
        #db = pymysql.connect(host=host, port=port, user=user, password=password, db=db, charset=charset)  #開啟資料庫連線
        db = pymysql.connect(host=host, port=port, user=user, password=password, db=db)  #開啟資料庫連線
        cursor = db.cursor()  #建立遊標物件

        line = cursor.execute(sql)   #執行sql,返回行數
        data = cursor.fetchall()   #fetchall返回查詢的全部資料， 返回元組型別資料
        # data = cursor.fetchone()   #fetchone只獲取一條資料， 返回元組型別資料
        # print(line)
        return data

    except Exception as msg:
        print(msg)
    finally:
        cursor.close()  #關掉遊標
        db.close()  #關掉資料庫連線
        
if __name__ == '__main__':
    buy_sell_2020Q1_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2020-01-02') x\
                            join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2020-03-31') y\
                            on x.sID = y.sID;"
    
    buy_sell_2020Q1 = read_data(buy_sell_2020Q1_sql)
#-----------------------------------------------------------------------------------
    buy_sell_2019Q4_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2019-10-01') x\
                            join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2019-12-31') y\
                            on x.sID = y.sID;"
    
    buy_sell_2019Q4 = read_data(buy_sell_2019Q4_sql)
    
#------------------------------------------------------------------------------------
    buy_sell_2019Q3_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2019-07-01') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2019-09-27') y\
                            on x.sID = y.sID;"
    buy_sell_2019Q3 = read_data(buy_sell_2019Q3_sql)
#--------------------------------------------------------------------------------
    buy_sell_2019Q2_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2019-04-01') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2019-06-28') y\
                            on x.sID = y.sID;"
    buy_sell_2019Q2 = read_data(buy_sell_2019Q2_sql)
    #-------------------------------------------------------------------------
    buy_sell_2019Q1_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2019-01-02') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2019-03-29') y\
                            on x.sID = y.sID;"
    buy_sell_2019Q1= read_data(buy_sell_2019Q1_sql)
    #-----------------------------------------------------------------
    buy_sell_2018Q4_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2018-10-01') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2018-12-28') y\
                            on x.sID = y.sID;"
    buy_sell_2018Q4= read_data(buy_sell_2018Q4_sql)
    #-------------------------------------------------------------------
    buy_sell_2018Q3_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2018-07-02') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2018-09-28') y\
                            on x.sID = y.sID;"
    buy_sell_2018Q3= read_data(buy_sell_2018Q3_sql)
    #----------------------------------------------------------------------
    buy_sell_2018Q2_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2018-04-02') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2018-07-02') y\
                            on x.sID = y.sID;"
    buy_sell_2018Q2= read_data(buy_sell_2018Q2_sql)
    #----------------------------------------------------------------------
    buy_sell_2018Q1_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2018-01-02') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2018-03-31') y\
                            on x.sID = y.sID;"
    buy_sell_2018Q1= read_data(buy_sell_2018Q1_sql)
    #---------------------------------------------------------------------------
    buy_sell_2017Q4_sql = "select x.sID,x.Date as buy_date, x.close as buy_price, y.Date as sell_date, y.close as sell_price\
                            from\
                            (SELECT sID,Date, close  FROM twstock.transactions \
                            where Date = '2017-10-02') x\
                            left join \
                            (SELECT sID,Date, close FROM twstock.transactions \
                            where Date = '2017-12-29') y\
                            on x.sID = y.sID;"
    buy_sell_2017Q4= read_data(buy_sell_2017Q4_sql)
    #-----------------------------------------------------------------
    EPS_sql = "SELECT sID,season, value as EPS FROM twstock.profitloss where code = '9850';"
    EPS = read_data(EPS_sql)

# %%
buy_sell_2020Q1 = pd.DataFrame(list(buy_sell_2020Q1),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2020Q1['season'] = '2020_Q1'
# print(buy_sell_2020Q1)

buy_sell_2019Q4 = pd.DataFrame(list(buy_sell_2019Q4),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2019Q4['season'] = '2019_Q4'
buy_sell_2019Q4

buy_sell_2019Q3 = pd.DataFrame(list(buy_sell_2019Q3),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2019Q3['season'] = '2019_Q3'
buy_sell_2019Q3

buy_sell_2019Q2 = pd.DataFrame(list(buy_sell_2019Q2),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2019Q2['season'] = '2019_Q2'
buy_sell_2019Q2

buy_sell_2019Q1 = pd.DataFrame(list(buy_sell_2019Q1),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2019Q1['season'] = '2019_Q1'
buy_sell_2019Q1

buy_sell_2018Q4 = pd.DataFrame(list(buy_sell_2018Q4),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2018Q4['season'] = '2018_Q4'
buy_sell_2018Q4

buy_sell_2018Q3 = pd.DataFrame(list(buy_sell_2018Q3),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2018Q3['season'] = '2018_Q3'
buy_sell_2018Q3

buy_sell_2018Q2 = pd.DataFrame(list(buy_sell_2018Q2),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2018Q2['season'] = '2018_Q2'
buy_sell_2018Q2

buy_sell_2018Q1 = pd.DataFrame(list(buy_sell_2018Q1),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2018Q1['season'] = '2018_Q1'
buy_sell_2018Q1

buy_sell_2017Q4 = pd.DataFrame(list(buy_sell_2017Q4),columns = ['sID','buy_date','buy_price','sell_date','sell_price'])
buy_sell_2017Q4['season'] = '2017_Q4'
buy_sell_2017Q4
# Out:
#       sID    buy_date  buy_price   sell_date  sell_price   season
# 0    1101  2017-10-02      33.65  2017-12-29       36.45  2017_Q4
# 1    1102  2017-10-02      26.90  2017-12-29       28.20  2017_Q4
# 2    1103  2017-10-02      12.65  2017-12-29       13.35  2017_Q4
# 3    1104  2017-10-02      23.25  2017-12-29       22.95  2017_Q4
# 4    1108  2017-10-02       8.77  2017-12-29        8.37  2017_Q4
# ..    ...         ...        ...         ...         ...      ...
# 874  9944  2017-10-02      18.50  2017-12-29       19.60  2017_Q4
# 875  9945  2017-10-02      28.30  2017-12-29       31.95  2017_Q4
# 876  9946  2017-10-02      10.85  2017-12-29       12.75  2017_Q4
# 877  9955  2017-10-02      14.05  2017-12-29       15.10  2017_Q4
# 878  9958  2017-10-02      16.55  2017-12-29       21.20  2017_Q4
#
# [879 rows x 6 columns]

# %%
frames = [buy_sell_2020Q1,buy_sell_2019Q4,buy_sell_2019Q3,buy_sell_2019Q2,buy_sell_2019Q1,buy_sell_2018Q4,buy_sell_2018Q3,buy_sell_2018Q2,buy_sell_2018Q1,buy_sell_2017Q4]
all_buy_sell = pd.concat(frames)
all_buy_sell['sID'] = all_buy_sell['sID'].astype('int64')

# %%
finance_index = pd.read_csv('finance_index.csv',index_col='Unnamed: 0')
finance_index
# Out:
#        sID   A1    A2     A3    A4     A5     A6    A7       A8      A9  ...  \
# 0     1101  0.0  5.12   9.15  3.83  14.20  17.59  1.14    88.17   15.41  ...
# 1     1101  0.0  1.64   2.81  1.06  19.23  25.29  0.21    48.01   13.40  ...
# 2     1101  0.0  2.90   5.40  2.70  26.95  38.95  0.93   119.02   39.90  ...
# 3     1101  0.0  2.38   3.96  2.24  22.85  31.19  1.25   197.25   57.07  ...
# 4     1101  0.0  8.19  14.28  7.34  22.62  30.97  1.80    78.60   21.27  ...
# ...    ...  ...   ...    ...   ...    ...    ...   ...      ...     ...  ...
# 9684  9958  0.0  0.32   0.66  0.08   8.12   9.67  1.12  1158.05   98.33  ...
# 9685  9958  0.0  0.21   0.44  0.01   4.73   5.45  1.53  2448.80  128.59  ...
# 9686  9958  0.0 -0.85  -1.55  5.91 -15.05 -15.66  0.24  -106.34   35.97  ...
# 9687  9958  0.0  1.03   2.06  6.44   4.82   5.70 -0.29  -108.09    0.64  ...
# 9688  9958  0.0  1.10   2.34  0.95  11.43  14.08  0.22    72.48    9.54  ...
#
# ...

# %%
EPS = pd.DataFrame(list(EPS),columns = ['sID','season','EPS'])
EPS['sID'] = EPS['sID'].astype('int64')
EPS.info()
# EPS['shift'] = EPS[['EPS']].shift(-1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10787 entries, 0 to 10786
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sID     10787 non-null  int64
#  1   season  10787 non-null  object
#  2   EPS     10787 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 252.9+ KB

# %%
data = pd.merge(all_buy_sell,finance_index,on = ['sID','season'])
data = pd.merge(data,EPS,on = ['sID','season'])
data
# Out:
#        sID    buy_date  buy_price   sell_date  sell_price   season   A1  \
# 0     1101  2020-01-02      44.10  2020-03-31       39.50  2020_Q1  0.0
# 1     1102  2020-01-02      48.90  2020-03-31       39.40  2020_Q1  0.0
# 2     1103  2020-01-02      22.35  2020-03-31       15.15  2020_Q1  0.0
# 3     1104  2020-01-02      19.65  2020-03-31       15.80  2020_Q1  0.0
# 4     1108  2020-01-02       8.37  2020-03-31        6.31  2020_Q1  0.0
